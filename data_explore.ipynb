# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/ruijisun/Desktop/All TherMOOstat Feedback.csv')

# %%
df.head()
# Out:
#            Date                 Building Name  Room Comfort Physical Activity  \
# 0  1/2/16 16:45               Shields Library   NaN    Cold               NaN
# 1  1/3/16 19:29                  Wellman Hall     2     Hot               NaN
# 2   1/4/16 8:04  University Services Building   145  Chilly               NaN
# 3   1/4/16 8:34                  Wellman Hall     3    Warm               NaN
# 4   1/4/16 8:58                   Haring Hall  2205     Hot               NaN
#
#   Clothing Level Comment  Email_ID
# 0            NaN     NaN    2227.0
# 1            NaN     NaN    1067.0
# 2            NaN     NaN    5881.0
# 3            NaN     NaN    4749.0
# 4            NaN     NaN    6934.0

# %%
# count each person's votes
df_id = df.groupby(['Email_ID']).count()
df_id
# Out:
#           Date  Building Name  Room  Comfort  Physical Activity  \
# Email_ID
# 1.0          2              2     2        2                  2
# 2.0          2              2     2        2                  2
# 3.0          1              1     1        1                  1
# 4.0          1              1     1        1                  1
# 5.0          3              3     3        3                  3
# ...        ...            ...   ...      ...                ...
# 8746.0       2              2     2        2                  2
# 8747.0       1              1     1        1                  1
# 8748.0       1              1     1        1                  1
# 8749.0       1              1     1        1                  1
# 8750.0       1              1     1        1                  0
#
#           Clothing Level  Comment
# Email_ID
# 1.0                    2        2
# 2.0                    2        0
# 3.0                    1        0
# 4.0                    1        0
# ...

# %%
# how many votes would one person submit?
df_id.sort_values('Comfort')
# Out:
#           Date  Building Name  Room  Comfort  Physical Activity  \
# Email_ID
# 2533.0       1              1     1        0                  0
# 5088.0       1              1     1        0                  0
# 5544.0       1              1     1        0                  0
# 6814.0       1              1     1        0                  0
# 2838.0       1              1     1        0                  0
# ...        ...            ...   ...      ...                ...
# 1352.0      45             45    45       45                 39
# 7787.0      45             45    45       45                 32
# 6157.0      46             46    46       46                 21
# 2305.0      59             59    59       57                  5
# 4735.0      66             66    66       65                 30
#
#           Clothing Level  Comment
# Email_ID
# 2533.0                 0        0
# 5088.0                 0        0
# 5544.0                 0        0
# 6814.0                 0        0
# ...
